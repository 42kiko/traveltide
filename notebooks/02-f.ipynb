# %%
import pandas as pd
from src.setup import get_base
from src.feature_engineering import engineer_features

# %%
df = get_base()

# %%
df
# Out:
#                                     session_id  user_id  \
# 0      101486-6d053e0f51884dddb339416c86d5b3a9   101486
# 1      101486-6de2ac91a8c24619a69a3d3ae7c28d61   101486
# 2      101486-7e8b450e5fe94345bd6c1ae9f479f073   101486
# 3      101486-9e7d5ccc7e034bf7b7a5ad2f3befbe13   101486
# 4      101486-be6d02b11839441aa4107044d095cb99   101486
# ...                                        ...      ...
# 49099   94883-a7021e0950814faa8fb9045613065658    94883
# 49100   94883-b74774da212f4ceea8647085ca2f4a30    94883
# 49101   94883-d6ab30bec3474af684c9af4d299bfc2d    94883
# 49102   94883-ec6cc8bb0a7441739923714e2f75bceb    94883
# 49103   94883-f649e048680a4119afc2ef90eec3c7f0    94883
#
#                                       trip_id       session_start  \
# 0                                         NaN 2023-07-18 09:35:00
# 1                                         NaN 2023-03-21 10:16:00
# 2                                         NaN 2023-02-11 17:05:00
# ...

# %%
df_features = engineer_features(df)

# %%
display(df_features)
display(df_features.head())
# Out:
#          age  gender  married  has_children  avg_clicks  total_clicks  \
# user_id
# 23557     66     0.0        1             0      10.250            82
# 94883     53     0.0        1             0       9.125            73
# 101486    52     0.0        1             1      16.375           131
# 101961    45     0.0        1             0      15.750           126
# 106907    46     0.0        1             1      30.000           240
# ...      ...     ...      ...           ...         ...           ...
# 792549    47     0.0        0             0      14.250           114
# 796032    52     0.0        1             0      18.500           148
# 801660    55     0.0        1             1      14.375           115
# 811077    46     0.0        1             1      13.125           105
# 844489    25     1.0        0             1      12.375            99
#
#          total_cancellation  avg_session_duration  total_session_duration  \
# user_id
# ...

# %%
df_features['total_people'].unique()
# Out:
# array([ 3.,  5., 12.,  8.,  1.,  4.,  6.,  0.,  2., 10.,  7., 11.,  9.,
#        14., 15., 13., 17., 16.])
