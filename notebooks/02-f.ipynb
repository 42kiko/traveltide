# %%
import pandas as pd
from src.setup import get_base
from src.feature_engineering import engineer_features

# %%
df = get_base()

# %%
df_features = engineer_features(df)

# %%
display(df_features)
display(df_features.head())
# Out:
#          age  gender  married  has_children  avg_clicks  total_clicks  \
# user_id
# 23557     66     0.0        1             0      10.250            82
# 94883     53     0.0        1             0       9.125            73
# 101486    52     0.0        1             1      16.375           131
# 101961    45     0.0        1             0      15.750           126
# 106907    46     0.0        1             1      30.000           240
# ...      ...     ...      ...           ...         ...           ...
# 792549    47     0.0        0             0      14.250           114
# 796032    52     0.0        1             0      18.500           148
# 801660    55     0.0        1             1      14.375           115
# 811077    46     0.0        1             1      13.125           105
# 844489    25     1.0        0             1      12.375            99
#
#          total_cancellation  avg_session_duration  total_session_duration  \
# user_id
# 23557                     0              1.277083               10.216667
# 94883                     0              1.129167                9.033333
# 101486                    0              2.037500               16.300000
# 101961                    0              1.962500               15.700000
# 106907                    1             12.648584              101.188675
# ...                     ...                   ...                     ...
# 792549                    0              1.781250               14.250000
# 796032                    1              9.088659               72.709272
# 801660                    0              1.766667               14.133333
# 811077                    0              1.652083               13.216667
# 844489                    0              1.552083               12.416667
#
#          total_sessions  avg_flight_discount  total_flight_discount  \
# user_id
# 23557                 8                0.000                      0
# 94883                 8                0.000                      0
# 101486                8                0.250                      2
# 101961                8                0.250                      2
# 106907                8                0.125                      1
# ...                 ...                  ...                    ...
# 792549                8                0.125                      1
# 796032                8                0.250                      2
# 801660                8                0.375                      3
# 811077                8                0.250                      2
# 844489                8                0.125                      1
#
#          avg_hotel_discount  total_hotel_discount  total_flights_booked  \
# user_id
# 23557                 0.250                     2                     0
# 94883                 0.125                     1                     2
# 101486                0.000                     0                     1
# 101961                0.125                     1                     5
# 106907                0.125                     1                     2
# ...                     ...                   ...                   ...
# 792549                0.000                     0                     4
# 796032                0.125                     1                     4
# 801660                0.000                     0                     3
# 811077                0.125                     1                     1
# 844489                0.125                     1                     0
#
#          total_hotels_booked  avg_flight_fare_usd  total_flight_fare_usd  \
# user_id
# 23557                      2             0.000000                   0.00
# 94883                      2           432.045000                 864.09
# 101486                     2           189.910000                 189.91
# 101961                     5           248.532000                1242.66
# 106907                     2         13902.060000               27804.12
# ...                      ...                  ...                    ...
# 792549                     1           259.792500                1039.17
# 796032                     3          1305.410000                5221.64
# 801660                     3           136.653333                 409.96
# 811077                     1           579.790000                 579.79
# 844489                     0             0.000000                   0.00
#
#          n_unique_destinations
# user_id
# 23557                        0
# 94883                        2
# 101486                       1
# 101961                       5
# 106907                       1
# ...                        ...
# 792549                       4
# 796032                       3
# 801660                       1
# 811077                       1
# 844489                       0
#
# [5998 rows x 19 columns]
#          age  gender  married  has_children  avg_clicks  total_clicks  \
# user_id
# 23557     66     0.0        1             0      10.250            82
# 94883     53     0.0        1             0       9.125            73
# 101486    52     0.0        1             1      16.375           131
# 101961    45     0.0        1             0      15.750           126
# 106907    46     0.0        1             1      30.000           240
#
#          total_cancellation  avg_session_duration  total_session_duration  \
# user_id
# 23557                     0              1.277083               10.216667
# 94883                     0              1.129167                9.033333
# 101486                    0              2.037500               16.300000
# 101961                    0              1.962500               15.700000
# 106907                    1             12.648584              101.188675
#
#          total_sessions  avg_flight_discount  total_flight_discount  \
# user_id
# 23557                 8                0.000                      0
# 94883                 8                0.000                      0
# 101486                8                0.250                      2
# 101961                8                0.250                      2
# 106907                8                0.125                      1
#
#          avg_hotel_discount  total_hotel_discount  total_flights_booked  \
# user_id
# 23557                 0.250                     2                     0
# 94883                 0.125                     1                     2
# 101486                0.000                     0                     1
# 101961                0.125                     1                     5
# 106907                0.125                     1                     2
#
#          total_hotels_booked  avg_flight_fare_usd  total_flight_fare_usd  \
# user_id
# 23557                      2                0.000                   0.00
# 94883                      2              432.045                 864.09
# 101486                     2              189.910                 189.91
# 101961                     5              248.532                1242.66
# 106907                     2            13902.060               27804.12
#
#          n_unique_destinations
# user_id
# 23557                        0
# 94883                        2
# 101486                       1
# 101961                       5
# 106907                       1
